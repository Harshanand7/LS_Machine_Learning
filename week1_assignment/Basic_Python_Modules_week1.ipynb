# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshanand7/LS_Machine_Learning/blob/main/week1_assignment/Basic_Python_Modules_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy Implementation

# %%
import numpy as np
# Create a 2D Numpy array of size 1x3 with elements of your choice
arr1=np.ones((1,3))

# Create a Numpy array of length 50 with zeroes as its elements
arr2=np.zeros(50)

#Create a Numpy array of length 3x2 with elements of your choice
arr3=np.ones((3,2))
#Multiply arr1 and arr3 using Numpy functions
arr4=np.matmul(arr1,arr3)

#Change 5th element of arr2 to a different number
arr2[4]=123

print(arr4.shape)
print(arr4)
#Your code here

if np.shape(arr4)==(1, 2) and arr2[4]!=0:
  print("Passed")
else:
  print("Fail")
# Out:
# (1, 2)
# [[3. 3.]]
# Passed

# %%
import numpy as np
arrI=np.identity(3)
arr2=np.identity(3)*9+1
print(np.dot(arrI,arr2))

#Task: Perform the dot product of I and 9I+1 using numpy, here I is referred to as an 3x3 Identity matrix.
# Out:
# [[10.  1.  1.]
#  [ 1. 10.  1.]
#  [ 1.  1. 10.]]

# %% [markdown]
# # Pandas Implementation

# %%
import pandas as pd

## Create a DataFrame from a dictionary
data = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, 30, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}
#Your code here

#Display the first 2 rows of the data frame

#Your code here
data=pd.DataFrame(data)
print(data.iloc[:2,:])

#Print the age column

#Your code here
print(data['Age'])
#Filter rows where age is greater than 26

#Your code here
print(data[data['Age']>26])
#Add a new column 'Country' with the value 'India' for all rows
#Your code here
Country=pd.Series(['India']*len(data))
data['Country']=Country
print(data)


data1 = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, None, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}

df2= pd.DataFrame(data1)
df2['Age'].fillna(df2['Age'].mean(),inplace=True)
print(df2)
# Fill missing values in the 'Age' column with the mean age
#Your code here
# Out:
#      Name  Age       City
# 0  Ramesh   25  Bangalore
# 1  Mahesh   30     Mumbai
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64
#      Name  Age    City
# 1  Mahesh   30  Mumbai
# 2  Suresh   35   Delhi
#      Name  Age       City Country
# 0  Ramesh   25  Bangalore   India
# 1  Mahesh   30     Mumbai   India
# 2  Suresh   35      Delhi   India
#      Name   Age       City
# 0  Ramesh  25.0  Bangalore
# 1  Mahesh  30.0     Mumbai
# 2  Suresh  35.0      Delhi

# %% [markdown]
# # Matplotlib Implementation

# %%
import matplotlib.pyplot as plt
import numpy as np



xpoints=np.array([1,2,3,4])
ypoints=np.array([2,4,6,8])

#Plot these points without drawing a line
#Your code here
plt.figure()
plt.scatter(xpoints,ypoints)

plt.show()

#Plotting with marker: Plot these points with a marker(Star marker)
#Your code here
plt.figure()
plt.scatter(xpoints,ypoints,marker='*')

plt.show()
#Using fmt format, add circular marker,red color and Dashed line
#Your code here
plt.figure()
plt.plot(xpoints,ypoints,marker='o',c='r',linestyle='--')


#Add xlabel,ylabel and title for the plot.
#Your code here
plt.figure()
plt.plot(xpoints,ypoints,marker='*')
plt.xlabel('Xpoints')
plt.ylabel('Ypoints')
plt.show()
#Create a scatter plot for xpoints and ypoints
#Your code here
plt.figure()
plt.scatter(xpoints,ypoints,marker='*',c='y')
plt.xlabel('Xpoints')
plt.ylabel('Ypoints')
plt.show()

#Set color to the scatter plot. Blue,Green,Red and yellow color for each point respectively
plt.figure()
plt.scatter(xpoints,ypoints,marker='*',c=['b','g','r','y'])
plt.xlabel('Xpoints')
plt.ylabel('Ypoints')
plt.show()

# %% [markdown]
# # Miscellaneous Modules Implementation

# %%
import random
import numpy as np

#Set the seed of random to 20
random.seed(20)

#Your code here

arr1=np.array([1,24,31,45,73,81,94,25])
arr1_list=arr1.tolist()
#Using the random module pick 4 different random numbers from arr1 and return their sum.
print(sum(random.sample(arr1_list,4)))
#Your code here
# Out:
# 138
